# %%
# !pip install pythainlp
# Out:
# ...
#      |████████████████████████████████| 11.0 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 743 kB 26.0 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.2 which is incompatible.
# ...

# %%
#@title Default title text
str1 = "" #@param {type:"string"}

# %% [markdown]
# #Section

# %% [markdown]
# **hello**
# *Italic*
# (link)(https://google.com)

# %% [markdown]
# ## Code Cell

# %%
x = 2+3

# %%
x
# Out:
# 5

# %%
print(x)
# Out:
# 5

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## Import Library

# %%
import numpy
import matplotlib.pyplot as plt

# %%
x = numpy.array([1,2,3,4,5])
y = 2*x

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# #Install Lib

# %%
import pythainlp

# %% [markdown]
# #Session Storage

# %%
import pandas as pd
from matplotlib import pyplot as plot

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/

# %%
df = pd.read_excel('Mentors contact email.xlsx')
df.info
# Out:
# <bound method DataFrame.info of     ลำดับ  ...                        Email
# 0     NaN  ...                       GISTDA
# 1     1.0  ...          likhit@gistda.or.th
# 2     2.0  ...         tayodit@gistda.or.th
# 3     3.0  ...            phat@gistda.or.th
# 4     4.0  ...    chonmanart.n@gistda.or.th
# 5     5.0  ...         sutee.c@gistda.or.th
# 6     6.0  ...         poonsak@gistda.or.th
# 7     7.0  ...  Chidchanok.cha@gistda.or.th
# 8     8.0  ...          atipat@gistda.or.th
# 9     9.0  ...       tananitip@gistda.or.th
# 10   10.0  ...       teerapat@gistda.or.th
# 11   11.0  ...         paripat@gistda.or.th
# 12   12.0  ...        panachai@gistda.or.th
# 13   13.0  ...       panatchai@gistda.or.th
# 14   14.0  ...         narawit@gistda.or.th
# 15   15.0  ...        aroonsak@gistda.or.th
# 16   16.0  ...           wasan@gistda.or.th
# 17   17.0  ...        nathanan@gistda.or.th
#
# [18 rows x 5 columns]>

# %%
df
# Out:
#     ลำดับ  ...                        Email
# 0     NaN  ...                       GISTDA
# 1     1.0  ...          likhit@gistda.or.th
# 2     2.0  ...         tayodit@gistda.or.th
# 3     3.0  ...            phat@gistda.or.th
# 4     4.0  ...    chonmanart.n@gistda.or.th
# 5     5.0  ...         sutee.c@gistda.or.th
# 6     6.0  ...         poonsak@gistda.or.th
# 7     7.0  ...  Chidchanok.cha@gistda.or.th
# 8     8.0  ...          atipat@gistda.or.th
# 9     9.0  ...       tananitip@gistda.or.th
# 10   10.0  ...       teerapat@gistda.or.th
# 11   11.0  ...         paripat@gistda.or.th
# 12   12.0  ...        panachai@gistda.or.th
# 13   13.0  ...       panatchai@gistda.or.th
# 14   14.0  ...         narawit@gistda.or.th
# 15   15.0  ...        aroonsak@gistda.or.th
# 16   16.0  ...           wasan@gistda.or.th
# 17   17.0  ...        nathanan@gistda.or.th
#
# [18 rows x 5 columns]

# %% [markdown]
# #Form

# %%
#@title Form
text = "Hello" #@param {type:"string"}
slide = 0 #@param {type:"slider", min:0, max:100, step:1}

# %% [markdown]
# #Google Drive

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  ภาษี/
# '002 Advance Course A1 VCD template.xlsx'
#  0102Feigin20.pdf
#  10_19_2016_161455948.xlsx
#  10257492_533525813426058_8558401038650198951_n.jpg
#  10486020_10203424486070202_6263856156801292249_o.jpg
#  11-Creative-Cases-for-Creating-Event-Experience.pdf
# 'งานที่ 1 เขต 4.rar'
#  16016734.pdf
#  1606643302696.jfif
#  1960945_743546372376356_2459486176072372018_o.jpg
#  1da76087-9074-48c2-9c63-ac095c146742.pdf
#  1.pdf
# '1. Whitepaper ESS.gdoc'
#  200430_Swan_handout.pdf
#  2012_OPN_Alexfeature.pdf
#  20171212_111509.amr
#  2018-09-18-de08ad18e624635e8bcfe166640a2a54.pdf
#  20190816_ToPrint/
#  20200224_RESUME_NUTTAPON-NAKARACH.gdoc
#  20200224_RESUME_NUTTAPON-NAKARACH.pdf
#  2020_Book_ProgrammingForComputations-Pyt.pdf
# '#2021'/
# 'อัพเดตสินเชื่อบ้านรีไฟแนนซ์ ครึ่งปีแรก 2559 | เตรียมตัวก่อนซื้อ | PropertyGuru Thailand.pdf'
# '2. National Roadmap ESS.gdoc'
# 'งานที่ 2 สสจ นนทบุรี.rar'
#  300-Professional-Lightroom-Presets.7z
#  31b438af-8f08-436d-be41-fd1f395c4f82.pdf
# ...

# %% [markdown]
# #Github Version Control

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
cd GitHub/
# Out:
# /content/drive/My Drive/GitHub

# %%
ls

# %%
git clone https://github.com/invalder/colab_course.git
# Out:
#   File "<ipython-input-11-b292ca7a06ed>", line 1
#     git clone https://github.com/invalder/colab_course.git
#             ^
# SyntaxError: invalid syntax

# %%
# %git clone https://github.com/invalder/colab_course.git
# Out:
# UsageError: Line magic function `%git` not found.

# %%
# !git clone https://github.com/invalder/colab_course.git
# Out:
# Cloning into 'colab_course'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
ls
# Out:
# colab_course/

# %%
cd colab_course
# Out:
# /content/drive/My Drive/GitHub/colab_course

# %%
ls

# %%
ls -al
# Out:
# total 6
# drwx------ 8 root root 4096 Sep 20 14:07 .git/
# -rw------- 1 root root 1799 Sep 20 14:07 .gitignore

# %%
ls -al
# Out:
# total 6
# drwx------ 8 root root 4096 Sep 20 14:07 .git/
# -rw------- 1 root root 1799 Sep 20 14:07 .gitignore

# %%
ls -al
# Out:
# total 59
# drwx------ 8 root root  4096 Sep 20 14:07 .git/
# -rw------- 1 root root  1799 Sep 20 14:07 .gitignore
# -rw------- 1 root root 53920 Sep 20 14:12 hands_on.ipynb

# %%
# !git add .
# !git config --global user.email "ponidc@gmail.com"
# !git config --global user.name "Nuttapon N"
# !git commit
